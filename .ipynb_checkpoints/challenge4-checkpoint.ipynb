# %%
import pandas as pd

# %%
# Séparation des colonnes par les ;

# %%
df_google_ap_1 = pd.read_csv("googleplaystore_1.csv", sep=";")

# %%
result = df_google_ap_1[df_google_ap_1["Installs"] == "1,000,000,000+"]

# %%
result
# Out:
#                                           App             Category Rating  \
# 139                         Google Play Books  BOOKS_AND_REFERENCE    3.9
# 313  Messenger – Text and Video Chat for Free        COMMUNICATION    4.0
# 314                        WhatsApp Messenger        COMMUNICATION    4.4
# 316              Google Chrome: Fast & Secure        COMMUNICATION    4.3
# 318                                     Gmail        COMMUNICATION    4.3
# 319                                  Hangouts        COMMUNICATION    4.0
# 359                        WhatsApp Messenger        COMMUNICATION    4.4
# 360  Messenger – Text and Video Chat for Free        COMMUNICATION    4.0
# 364                                  Hangouts        COMMUNICATION    4.0
# 368             Skype - free IM & video calls        COMMUNICATION    4.1
# 386              Google Chrome: Fast & Secure        COMMUNICATION    4.3
# 424                                     Gmail        COMMUNICATION    4.3
# ...

# %%
# Affichage des cols App , Category , Genres contenant + 1 000 000 000 d'installation

# %%
cols = ["App","Category","Genres"]
result[cols]
# Out:
#                                           App             Category  \
# 139                         Google Play Books  BOOKS_AND_REFERENCE
# 313  Messenger – Text and Video Chat for Free        COMMUNICATION
# 314                        WhatsApp Messenger        COMMUNICATION
# 316              Google Chrome: Fast & Secure        COMMUNICATION
# 318                                     Gmail        COMMUNICATION
# 319                                  Hangouts        COMMUNICATION
# 359                        WhatsApp Messenger        COMMUNICATION
# 360  Messenger – Text and Video Chat for Free        COMMUNICATION
# 364                                  Hangouts        COMMUNICATION
# 368             Skype - free IM & video calls        COMMUNICATION
# 386              Google Chrome: Fast & Secure        COMMUNICATION
# 424                                     Gmail        COMMUNICATION
# 436                                  Hangouts        COMMUNICATION
# ...

# %%
avis = df_google_ap_1["Reviews"]

# %%
# Valeur max d'avis

# %%
avis.max()
# Out:
# 69119316.0

# %%
# Index contenant la valeur max d'avis

# %%
avis.argmax()
# Out:
# 314

# %%
# Ligne de l'index 314

# %%
df_google_ap_1.iloc[314]
# Out:
# App               WhatsApp Messenger
# Category               COMMUNICATION
# Rating                           4.4
# Reviews                   69119316.0
# Size              Varies with device
# Installs              1,000,000,000+
# Type                            Free
# Price                              0
# Content Rating              Everyone
# Genres                 Communication
# Last Updated          August 3, 2018
# Current Ver       Varies with device
# Android Ver       Varies with device
# Name: 314, dtype: object

# %%
# L'appli concerné est WhatsApp Messeger et la note de 4.4

# %%
df_google_ap_1.iloc[3:17,[2,5,6]]
# Out:
#    Rating     Installs  Type
# 3     4.3     100,000+  Free
# 4     4.4      50,000+  Free
# 5     3.8      50,000+  Free
# 6     4.1   1,000,000+  Free
# 7     4.4   1,000,000+  Free
# 8     4.7      10,000+  Free
# 9     4.4   1,000,000+  Free
# 10    4.4   1,000,000+  Free
# 11    4.2  10,000,000+  Free
# 12    4.6     100,000+  Free
# 13    4.4     100,000+  Free
# 14    3.2       5,000+  Free
# 15    4.7     500,000+  Free
# 16    4.5      10,000+  Free

# %%
age = df_google_ap_1[df_google_ap_1["Content Rating"] == "Everyone"]

# %%
age
# Out:
#                                                 App        Category Rating  \
# 0    Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN    4.1
# 1                               Coloring book moana  ART_AND_DESIGN    3.9
# 3             Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN    4.3
# 4                        Paper flowers instructions  ART_AND_DESIGN    4.4
# 5           Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN    3.8
# ..                                              ...             ...    ...
# 444                    Glide - Video Chat Messenger   COMMUNICATION    4.3
# 445                    Talkray - Free Calls & Texts   COMMUNICATION    4.2
# 446                     LINE: Free Calls & Messages   COMMUNICATION    4.2
# 447                    KakaoTalk: Free Calls & Text   COMMUNICATION    4.3
# 448                                      Calculator          DATING    2.6
#
# ...

# %%
db_age = age.App.drop_duplicates()

# %%
len(db_age.axes[0])
# Out:
# 326

# %%
# il y a 326 apllications ouvertes aux personnes de tous âges

# %%
df_google_ap_1['Category'].mode()
# Out:
# 0    COMMUNICATION
# Name: Category, dtype: object

# %%
# la catégorie contenant le plus d'application est la catégorie "COMMUNICATION"

# %%
price = df_google_ap_1[df_google_ap_1["Price"] == "$7.99"]

# %%
price
# Out:
#                                                    App Category Rating  \
# 451  AMBW Dating App: Asian Men Black Women Interra...   DATING    3.5
#
#      Reviews Size Installs  Type  Price Content Rating  Genres  \
# 451      2.0  17M     100+  Paid  $7.99     Mature 17+  Dating
#
#          Last Updated Current Ver Android Ver
# 451  January 21, 2017       1.0.1  4.0 and up

# %%
# L'appli vendue la plus chère est AMBW Dating App
