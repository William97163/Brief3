# %%
import pandas as pd

# %%
erp = pd.read_excel("challenge_data\erp.xlsx")
erp
# Out:
# C:\Users\utilisateur\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#      product_id  onsale_web  price  stock_quantity stock_status
# 0          3847           1   24.2               0   outofstock
# 1          3849           1   34.3               0   outofstock
# 2          3850           1   20.8               0   outofstock
# 3          4032           1   14.1               0   outofstock
# 4          4039           1   46.0               0   outofstock
# ..          ...         ...    ...             ...          ...
# 820        7203           0   45.0              30      instock
# 821        7204           0   45.0               9      instock
# 822        7247           1   54.8              23      instock
# 823        7329           0   26.5              14      instock
# 824        7338           1   16.3              45      instock
#
# [825 rows x 5 columns]

# %%
liaison= pd.read_excel("challenge_data\liaison.xlsx")
liaison
# Out:
# C:\Users\utilisateur\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#      product_id   id_web
# 0          3847    15298
# 1          3849    15296
# 2          3850    15300
# 3          4032    19814
# 4          4039    19815
# ..          ...      ...
# 820        7203      NaN
# 821        7204      NaN
# 822        7247  13127-1
# 823        7329  14680-1
# 824        7338    16230
#
# [825 rows x 2 columns]

# %%
liaison_idw = liaison["id_web"]

# %%
#for ids in liaison_idw:
    #if pd.isnull(ids)==True:
       # print("c est null")

# %%
col_id = liaison["product_id"]
col_id
# Out:
# 0      3847
# 1      3849
# 2      3850
# 3      4032
# 4      4039
#        ...
# 820    7203
# 821    7204
# 822    7247
# 823    7329
# 824    7338
# Name: product_id, Length: 825, dtype: int64

# %%
verif = col_id == erp["product_id"]
verif
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 820    True
# 821    True
# 822    True
# 823    True
# 824    True
# Name: product_id, Length: 825, dtype: bool

# %%
for value in verif :
    if value == False:
        print("alerte")

# %%
df_m = erp.merge(liaison)

# %%
web = pd.read_excel("challenge_data\web.xlsx")
# Out:
# C:\Users\utilisateur\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
web
# Out:
#                       sku  virtual  downloadable  rating_count  \
# 0     bon-cadeau-25-euros        0             0             0
# 1                   15298        0             0             0
# 2                   15296        0             0             0
# 3                   15300        0             0             0
# 4                   19814        0             0             0
# ...                   ...      ...           ...           ...
# 1508                16135        0             0             0
# 1509                15891        0             0             0
# 1510                15887        0             0             0
# 1511              13127-1        0             0             0
# 1512                16230        0             0             0
#
#       average_rating  total_sales tax_status  tax_class  post_author  \
# 0                0.0         10.0    taxable        NaN          1.0
# ...

# %%
web = web.rename(columns = {"sku":"id_web"})

# %%
df_all = web.merge(df_m)

# %%
df_all
# Out:
#                    id_web  virtual  downloadable  rating_count  \
# 0     bon-cadeau-25-euros        0             0             0
# 1     bon-cadeau-25-euros        0             0             0
# 2                   15298        0             0             0
# 3                   15298        0             0             0
# 4                   15296        0             0             0
# ...                   ...      ...           ...           ...
# 9158                15887        0             0             0
# 9159              13127-1        0             0             0
# 9160              13127-1        0             0             0
# 9161                16230        0             0             0
# 9162                16230        0             0             0
#
#       average_rating  total_sales tax_status  tax_class  post_author  \
# 0                0.0         10.0    taxable        NaN          1.0
# ...

# %% [markdown]
# # Création de la colonne de chiffre d'affaire "turnover"

# %%
df_all = df_all.assign(turnover=lambda x: x.total_sales * x.price)
df_all
# Out:
#                    id_web  virtual  downloadable  rating_count  \
# 0     bon-cadeau-25-euros        0             0             0
# 1     bon-cadeau-25-euros        0             0             0
# 2                   15298        0             0             0
# 3                   15298        0             0             0
# 4                   15296        0             0             0
# ...                   ...      ...           ...           ...
# 9158                15887        0             0             0
# 9159              13127-1        0             0             0
# 9160              13127-1        0             0             0
# 9161                16230        0             0             0
# 9162                16230        0             0             0
#
#       average_rating  total_sales tax_status  tax_class  post_author  \
# 0                0.0         10.0    taxable        NaN          1.0
# ...

# %%
# affichage des colonnes uniquements importantes pour le chiffre d'affaire 
filter_product = df_all[df_all["post_type"] == "product"]
filter_product[["post_type","total_sales","price","turnover"]]
# Out:
#      post_type  total_sales  price  turnover
# 0      product         10.0   25.0     250.0
# 2      product          6.0   24.2     145.2
# 4      product          0.0   34.3       0.0
# 6      product          0.0   20.8       0.0
# 8      product          3.0   14.1      42.3
# ...        ...          ...    ...       ...
# 9153   product          5.0    8.4      42.0
# 9155   product          0.0   27.5       0.0
# 9157   product          0.0   69.0       0.0
# 9159   product          0.0   54.8       0.0
# 9161   product          0.0   16.3       0.0
#
# [896 rows x 4 columns]

# %%
# Chiifre d'affaire total
df_all["turnover"].sum()
# Out:
# 141137.2

# %%
import scipy.stats as stats
import numpy as np
import matplotlib.pyplot as plt

# %%
zscore = stats.zscore(df_all["price"])
zscore
# Out:
# 0      -0.411718
# 1      -0.411718
# 2      -0.449228
# 3      -0.449228
# 4       0.024338
#           ...
# 9158    1.651343
# 9159    0.985537
# 9160    0.985537
# 9161   -0.819642
# 9162   -0.819642
# Name: price, Length: 9163, dtype: float64

# %%
q3, q1 = np.percentile(df_all["price"], [75,25])

# %%
iqr = q3 - q1
iqr
# Out:
# 23.5

# %%
df_all = df_all[df_all["post_type"] == "product"]
df_all
# Out:
#                    id_web  virtual  downloadable  rating_count  \
# 0     bon-cadeau-25-euros        0             0             0
# 2                   15298        0             0             0
# 4                   15296        0             0             0
# 6                   15300        0             0             0
# 8                   19814        0             0             0
# ...                   ...      ...           ...           ...
# 9153                16135        0             0             0
# 9155                15891        0             0             0
# 9157                15887        0             0             0
# 9159              13127-1        0             0             0
# 9161                16230        0             0             0
#
#       average_rating  total_sales tax_status  tax_class  post_author  \
# 0                0.0         10.0    taxable        NaN          1.0
# ...

# %%
df_all = df_all.assign(zscore=zscore)
df_all = df_all.drop_duplicates()
df_all = df_all[pd.isnull(df_all["id_web"]) == False]
df_all.reset_index(inplace = True, drop = True)
df_all
# Out:
#                   id_web  virtual  downloadable  rating_count  average_rating  \
# 0    bon-cadeau-25-euros        0             0             0             0.0
# 1                  15298        0             0             0             0.0
# 2                  15296        0             0             0             0.0
# 3                  15300        0             0             0             0.0
# 4                  19814        0             0             0             0.0
# ..                   ...      ...           ...           ...             ...
# 709                16135        0             0             0             0.0
# 710                15891        0             0             0             0.0
# 711                15887        0             0             0             0.0
# 712              13127-1        0             0             0             0.0
# 713                16230        0             0             0             0.0
#
# ...

# %%
zc_supp = df_all[df_all["zscore"] >= 2]

# %%
y = df_all.index.to_list()
x = df_all["price"]
b = zc_supp.index.to_list()
a = zc_supp["price"]

plt.scatter(x,y,c="b")
plt.scatter(a,b,c="r")

# %%
df_all.boxplot(column="zscore")
# Out:
# <AxesSubplot:>

# %%
zc_supp.boxplot(column="zscore")
# Out:
# <AxesSubplot:>
